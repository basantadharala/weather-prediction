# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score,f1_score,precision_score
from sklearn.preprocessing import MinMaxScaler,LabelEncoder
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import sklearn

# %%
print(np.__version__)
print(pd.__version__)
print(sklearn.__version__)
# Out:
# 1.26.4
# 2.1.4
# 1.5.0

# %%
df = pd.read_csv('seattle-weather.csv')

# %%
df.head()
# Out:
#          date  precipitation  temp_max  temp_min  wind  weather
# 0  2012-01-01            0.0      12.8       5.0   4.7  drizzle
# 1  2012-01-02           10.9      10.6       2.8   4.5     rain
# 2  2012-01-03            0.8      11.7       7.2   2.3     rain
# 3  2012-01-04           20.3      12.2       5.6   4.7     rain
# 4  2012-01-05            1.3       8.9       2.8   6.1     rain

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1461 entries, 0 to 1460
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           1461 non-null   object
#  1   precipitation  1461 non-null   float64
#  2   temp_max       1461 non-null   float64
#  3   temp_min       1461 non-null   float64
#  4   wind           1461 non-null   float64
#  5   weather        1461 non-null   object
# dtypes: float64(4), object(2)
# memory usage: 68.6+ KB

# %%
df['date'].isnull().sum()
# Out:
# 0

# %%
df['weather'].unique()
# Out:
# array(['drizzle', 'rain', 'sun', 'snow', 'fog'], dtype=object)

# %%
df.describe()
# Out:
#        precipitation     temp_max     temp_min         wind
# count    1461.000000  1461.000000  1461.000000  1461.000000
# mean        3.029432    16.439083     8.234771     3.241136
# std         6.680194     7.349758     5.023004     1.437825
# min         0.000000    -1.600000    -7.100000     0.400000
# 25%         0.000000    10.600000     4.400000     2.200000
# 50%         0.000000    15.600000     8.300000     3.000000
# 75%         2.800000    22.200000    12.200000     4.000000
# max        55.900000    35.600000    18.300000     9.500000

# %%
df.drop(['date'], axis=1, inplace=True)

# %%
df.head()
# Out:
#    precipitation  temp_max  temp_min  wind  weather
# 0            0.0      12.8       5.0   4.7  drizzle
# 1           10.9      10.6       2.8   4.5     rain
# 2            0.8      11.7       7.2   2.3     rain
# 3           20.3      12.2       5.6   4.7     rain
# 4            1.3       8.9       2.8   6.1     rain

# %%
plt.scatter(df['precipitation'],df['temp_max'])
plt.xlabel('maximum temperature')
plt.ylabel('precipitation')
# Out:
# Text(0, 0.5, 'precipitation')

# %%
plt.scatter(df['precipitation'],df['wind'])
plt.xlabel('wind')
plt.ylabel('precipitation')
# Out:
# Text(0, 0.5, 'precipitation')

# %%
X = df.iloc[:, :-1].values
y = df.iloc[:, -1].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=2)

# %%
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
X_train
# Out:
# array([[0.02325581, 0.28688525, 0.32283465, 0.23076923],
#        [0.00536673, 0.46994536, 0.58661417, 0.53846154],
#        [0.        , 0.57377049, 0.71653543, 0.48351648],
#        ...,
#        [0.        , 0.57377049, 0.71653543, 0.16483516],
#        [0.        , 0.59016393, 0.67322835, 0.58241758],
#        [0.00894454, 0.43715847, 0.54330709, 0.38461538]])

# %%
X_test
# Out:
# array([[0.06440072, 0.30054645, 0.47637795, 0.26373626],
#        [0.34525939, 0.2704918 , 0.30314961, 0.63736264],
#        [0.        , 0.57377049, 0.75984252, 0.24175824],
#        ...,
#        [0.        , 0.78688525, 0.78346457, 0.38461538],
#        [0.02325581, 0.40710383, 0.5       , 0.28571429],
#        [0.02325581, 0.5       , 0.6496063 , 0.30769231]])

# %%
le = LabelEncoder()
y_train = le.fit_transform(y_train)
y_test = le.transform(y_test)

# %%
y_train
# Out:
# array([2, 2, 4, ..., 4, 4, 2])

# %%
y_test
# Out:
# array([2, 3, 4, 4, 2, 2, 4, 2, 4, 2, 4, 2, 2, 1, 4, 2, 2, 4, 2, 4, 2, 0,
#        2, 4, 3, 2, 2, 2, 4, 2, 2, 2, 2, 2, 4, 4, 2, 2, 2, 0, 2, 2, 2, 3,
#        2, 2, 4, 4, 2, 2, 2, 2, 2, 0, 1, 3, 2, 4, 2, 4, 4, 2, 0, 2, 2, 4,
#        4, 2, 2, 2, 2, 4, 4, 4, 4, 4, 2, 4, 2, 2, 2, 4, 1, 3, 2, 4, 4, 4,
#        2, 2, 4, 2, 2, 4, 1, 4, 2, 2, 4, 4, 2, 2, 2, 2, 4, 4, 4, 2, 2, 2,
#        4, 2, 4, 2, 4, 2, 4, 2, 4, 0, 1, 2, 2, 2, 2, 2, 2, 4, 4, 4, 4, 2,
#        2, 2, 4, 4, 4, 2, 4, 4, 2, 4, 2, 2, 2, 3, 2, 1, 2, 4, 2, 4, 2, 4,
#        4, 1, 4, 2, 2, 4, 0, 2, 4, 4, 4, 4, 2, 4, 4, 4, 2, 4, 4, 4, 1, 4,
#        4, 4, 4, 4, 4, 4, 4, 2, 4, 4, 4, 0, 4, 2, 4, 0, 4, 4, 4, 2, 3, 2,
#        2, 1, 2, 4, 2, 2, 4, 2, 4, 4, 2, 2, 0, 2, 2, 2, 4, 4, 4, 4, 4, 2,
#        2, 2, 4, 4, 2, 4, 4, 4, 4, 2, 2, 4, 4, 2, 4, 2, 4, 4, 4, 4, 2, 2,
#        4, 4, 1, 4, 2, 2, 4, 4, 3, 4, 4, 1, 4, 4, 4, 4, 2, 2, 4, 4, 4, 0,
#        2, 2, 2, 2, 4, 4, 4, 4, 2, 2, 2, 2, 2, 2, 2, 4, 4, 4, 2, 4, 2, 4,
# ...

# %%
model = RandomForestClassifier(random_state=2)
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=2)

# %%
y_pred = model.predict(X_test)

# %%
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))
# Out:
# [[2 2]
#  [3 3]
#  [4 4]
#  [4 4]
#  [2 2]
#  [2 2]
#  [4 4]
#  [2 2]
#  [4 4]
#  [2 2]
#  [1 4]
#  [2 2]
#  [2 2]
#  [4 1]
#  [4 4]
#  [2 2]
#  [2 2]
#  [4 4]
#  [2 2]
#  [4 4]
#  [2 2]
#  [4 0]
#  [2 2]
#  [4 4]
#  [2 3]
#  [2 2]
#  [2 2]
#  [2 2]
#  [4 4]
#  [2 2]
#  [2 2]
#  [2 2]
#  [2 2]
#  [2 2]
#  [4 4]
#  [4 4]
#  [2 2]
#  [2 2]
#  [2 2]
#  [4 0]
#  [2 2]
#  [2 2]
#  [2 2]
#  [3 3]
#  [2 2]
#  [2 2]
#  [4 4]
#  [4 4]
#  [2 2]
#  [2 2]
#  [2 2]
#  [2 2]
#  [2 2]
#  [4 0]
#  [4 1]
#  [3 3]
#  [2 2]
#  [4 4]
#  [2 2]
#  [4 4]
#  [4 4]
#  [2 2]
#  [4 0]
#  [2 2]
#  [2 2]
#  [4 4]
#  [4 4]
#  [2 2]
#  [2 2]
#  [2 2]
#  [2 2]
#  [4 4]
#  [4 4]
#  [4 4]
#  [1 4]
#  [4 4]
#  [2 2]
#  [4 4]
#  [2 2]
#  [2 2]
#  [2 2]
#  [4 4]
#  [4 1]
#  [2 3]
#  [2 2]
#  [4 4]
#  [4 4]
#  [4 4]
#  [2 2]
#  [4 2]
#  [4 4]
#  [2 2]
#  [2 2]
#  [4 4]
#  [4 1]
#  [4 4]
#  [2 2]
#  [2 2]
#  [4 4]
#  [4 4]
#  [2 2]
#  [2 2]
#  [2 2]
#  [4 2]
#  [4 4]
#  [4 4]
#  [4 4]
#  [3 2]
#  [2 2]
#  [2 2]
#  [4 4]
# ...

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.860655737704918

# %%
f1 = f1_score(y_test, y_pred,average='micro')
precision = precision_score(y_test, y_pred,average='micro')
print(f1)
print(precision)
# Out:
# 0.860655737704918
# 0.860655737704918

# %%
lr = LogisticRegression(random_state=2)
lr.fit(X_train, y_train)
# Out:
# LogisticRegression(random_state=2)

# %%
accuracy_score(y_test, lr.predict(X_test))
# Out:
# 0.7431693989071039

# %%
f1_score = f1_score(y_test, lr.predict(X_test),average='micro')
precision_lr = precision_score(y_test, lr.predict(X_test),average='micro')
print(f1_score)
print(precision_lr)
# Out:
# 0.7431693989071039
# 0.7431693989071039

# %%
le.inverse_transform(model.predict([[0.0,	-5.0,	5.0,	5]]))
# Out:
# array(['sun'], dtype=object)

# %%
import pickle
pickle.dump(model, open('weather.pkl', 'wb'))

# %%
pickle.dump(scaler, open('scaler.pkl', 'wb'))
pickle.dump(le, open('le.pkl', 'wb'))
